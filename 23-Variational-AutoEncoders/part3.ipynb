# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from torchvision.utils import save_image

# %%
# Definee hyperparameters
image_size = 784
h_dim = 400
latent_dim = 20
batch_size = 128
num_epochs = 10

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# MNIST dataset
train_dataset = torchvision.datasets.MNIST(root='./data/',
                                             train=True,
                                                transform=transforms.ToTensor(),
                                                    download=True)

test_dataset = torchvision.datasets.MNIST(root='./data/',
                                            train=False,
                                                transform=transforms.ToTensor())

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                                  batch_size=batch_size,
                                                        shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                                    batch_size=batch_size,
                                                            shuffle=False)

# Create a directory to savee the reconstructed and sampled images (if not exists)
sample_dir = 'results'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# ![vae](https://user-images.githubusercontent.com/30661597/78418103-a2047200-766b-11ea-8205-c7e5712715f4.png)

# %%
# Define the model
# VAE model
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        self.fc1 = nn.Linear(image_size, h_dim)
        self.fc2_mean = nn.Linear(h_dim, latent_dim) # mu
        self.fc2_logvar = nn.Linear(h_dim, latent_dim) # logvar
        
        self.fc3 = nn.Linear(latent_dim, h_dim)
        self.fc4 = nn.Linear(h_dim, image_size)
        
    def encode(self, x):
        h = F.relu(self.fc1(x))
        return self.fc2_mean(h), self.fc2_logvar(h)
    
    def reparameterize(self, mu, logvar):
        std = torch.exp(logvar/2) # standard deviation
        eps = torch.randn_like(std) # epsilon
        return mu + eps*std
    
    def decode(self, z):
        h = F.relu(self.fc3(z))
        return torch.sigmoid(self.fc4(h))
    
    def forward(self, x):
        mu, logvar = self.encode(x.view(-1, image_size))
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar
    
# Define model and optimizer
model = VAE().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# $Loss = -E[\log P(X | z)]+D_{K L}[N(\mu(X), \Sigma(X)) \| N(0,1)]$

# %% [markdown]
# #### $D_{K L}[N(\mu(X), \Sigma(X)) \| N(0,1)]=\frac{1}{2} \sum_{k}\left(\exp (\Sigma(X))+\mu^{2}(X)-1-\Sigma(X)\right)$

# %%
# Define loss function
def loss_function(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, image_size), reduction='sum')
    
    # KL divergence
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return BCE + KLD

# %%
# Define train function
def train(epoch):
    model.train()
    train_loss = 0
    for i, (images, _) in enumerate(train_loader):
        images = images.to(device)
        
        recon_batch, mu, logvar = model(images)
        loss = loss_function(recon_batch, images, mu, logvar)
        
        optimizer.zero_grad()
        loss.backward()
        train_loss += loss.item()
        optimizer.step()
        
        if i % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\t Average loss: {:.6f}'.format(
                epoch, i*len(images), len(train_loader.dataset),
                100.*i/len(train_loader),
                loss.item()/len(images)))
            
    print('====> Epoch: {} Average loss: {:.4f}'.format(
        epoch, train_loss/len(train_loader.dataset)))

# %%
# Define test function
def test(epoch):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for batch_idx, (images, _) in enumerate(test_loader):
            images = images.to(device)
            
            recon_batch, mu, logvar = model(images)
            test_loss += loss_function(recon_batch, images, mu, logvar).item()
            
            if batch_idx == 0:
                n = min(images.size(0), 8)
                comparison = torch.cat([images[:n],
                                       recon_batch.view(batch_size, 1, 28, 28)[:n]])
            
            # Save the reconstructed images
            save_image(comparison.cpu(), 'results/reconstruction_' + str(epoch) + '.png')
            
    test_loss /= len(test_loader.dataset)
    print('====> Test loss: {:.4f}'.format(test_loss))

# %%
# Train the model
for epoch in range(1, num_epochs+1):
    train(epoch)
    test(epoch)
    
    # Save the sampled images
    with torch.no_grad():
        z = torch.randn(batch_size, latent_dim).to(device)
        sample = model.decode(z).cpu()
        save_image(sample.view(batch_size, 1, 28, 28), 'results/sample_' + str(epoch) + '.png')
# Out:
# Train Epoch: 1 [0/60000 (0%)]	 Average loss: 549.263306
# Train Epoch: 1 [12800/60000 (21%)]	 Average loss: 184.436890
# Train Epoch: 1 [25600/60000 (43%)]	 Average loss: 156.663239
# Train Epoch: 1 [38400/60000 (64%)]	 Average loss: 142.783264
# Train Epoch: 1 [51200/60000 (85%)]	 Average loss: 130.364349
# ====> Epoch: 1 Average loss: 165.0513
# ====> Test loss: 127.6641
# Train Epoch: 2 [0/60000 (0%)]	 Average loss: 126.771881
# Train Epoch: 2 [12800/60000 (21%)]	 Average loss: 116.982536
# Train Epoch: 2 [25600/60000 (43%)]	 Average loss: 125.328293
# Train Epoch: 2 [38400/60000 (64%)]	 Average loss: 117.606461
# Train Epoch: 2 [51200/60000 (85%)]	 Average loss: 114.267776
# ====> Epoch: 2 Average loss: 121.3749
# ====> Test loss: 115.6545
# Train Epoch: 3 [0/60000 (0%)]	 Average loss: 117.622147
# Train Epoch: 3 [12800/60000 (21%)]	 Average loss: 117.376694
# Train Epoch: 3 [25600/60000 (43%)]	 Average loss: 112.711891
# Train Epoch: 3 [38400/60000 (64%)]	 Average loss: 113.572891
# Train Epoch: 3 [51200/60000 (85%)]	 Average loss: 112.659981
# ====> Epoch: 3 Average loss: 114.4816
# ====> Test loss: 111.8110
# Train Epoch: 4 [0/60000 (0%)]	 Average loss: 116.390991
# Train Epoch: 4 [12800/60000 (21%)]	 Average loss: 112.219711
# Train Epoch: 4 [25600/60000 (43%)]	 Average loss: 114.114830
# Train Epoch: 4 [38400/60000 (64%)]	 Average loss: 110.530838
# Train Epoch: 4 [51200/60000 (85%)]	 Average loss: 113.231636
# ====> Epoch: 4 Average loss: 111.5546
# ====> Test loss: 109.9430
# Train Epoch: 5 [0/60000 (0%)]	 Average loss: 111.323341
# Train Epoch: 5 [12800/60000 (21%)]	 Average loss: 112.761513
# Train Epoch: 5 [25600/60000 (43%)]	 Average loss: 109.209152
# Train Epoch: 5 [38400/60000 (64%)]	 Average loss: 111.647705
# Train Epoch: 5 [51200/60000 (85%)]	 Average loss: 111.541290
# ====> Epoch: 5 Average loss: 109.9045
# ====> Test loss: 108.4127
# Train Epoch: 6 [0/60000 (0%)]	 Average loss: 112.439415
# Train Epoch: 6 [12800/60000 (21%)]	 Average loss: 107.936813
# Train Epoch: 6 [25600/60000 (43%)]	 Average loss: 109.562210
# Train Epoch: 6 [38400/60000 (64%)]	 Average loss: 111.970230
# Train Epoch: 6 [51200/60000 (85%)]	 Average loss: 109.721878
# ====> Epoch: 6 Average loss: 108.7364
# ====> Test loss: 107.7080
# Train Epoch: 7 [0/60000 (0%)]	 Average loss: 107.798569
# Train Epoch: 7 [12800/60000 (21%)]	 Average loss: 108.685188
# Train Epoch: 7 [25600/60000 (43%)]	 Average loss: 112.462433
# Train Epoch: 7 [38400/60000 (64%)]	 Average loss: 102.949242
# Train Epoch: 7 [51200/60000 (85%)]	 Average loss: 108.861664
# ====> Epoch: 7 Average loss: 107.8712
# ====> Test loss: 106.9747
# Train Epoch: 8 [0/60000 (0%)]	 Average loss: 106.243561
# Train Epoch: 8 [12800/60000 (21%)]	 Average loss: 103.682159
# Train Epoch: 8 [25600/60000 (43%)]	 Average loss: 106.993469
# Train Epoch: 8 [38400/60000 (64%)]	 Average loss: 104.397888
# Train Epoch: 8 [51200/60000 (85%)]	 Average loss: 103.050980
# ====> Epoch: 8 Average loss: 107.2442
# ====> Test loss: 106.4121
# Train Epoch: 9 [0/60000 (0%)]	 Average loss: 107.790001
# Train Epoch: 9 [12800/60000 (21%)]	 Average loss: 108.440727
# Train Epoch: 9 [25600/60000 (43%)]	 Average loss: 102.885193
# Train Epoch: 9 [38400/60000 (64%)]	 Average loss: 105.256989
# Train Epoch: 9 [51200/60000 (85%)]	 Average loss: 106.470406
# ====> Epoch: 9 Average loss: 106.7085
# ====> Test loss: 106.1986
# Train Epoch: 10 [0/60000 (0%)]	 Average loss: 110.071808
# Train Epoch: 10 [12800/60000 (21%)]	 Average loss: 106.683266
# Train Epoch: 10 [25600/60000 (43%)]	 Average loss: 107.265701
# Train Epoch: 10 [38400/60000 (64%)]	 Average loss: 106.654404
# Train Epoch: 10 [51200/60000 (85%)]	 Average loss: 107.344345
# ====> Epoch: 10 Average loss: 106.2655
# ====> Test loss: 105.6931
